# %%
# !pip install mofapy2 
# !pip install mofax

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

from mofapy2.run.entry_point import entry_point
import mofax as mfx
from typing import Dict, List, Tuple, Optional
import warnings

# %% [markdown]
# ## Phase 2 — Model training
#
# 1. Data preparation
#     - Load proteomics, lipidomics, metabolomics.
#     - Separate the label row, convert measurements to numeric, set sample IDs as index.
#     - Ensure shapes and dtypes are correct before training.
#
# 2. MOFA+ training
#     - 2.1 MOFA+ runs
#       - Run 1 — Full data + only ARD
#          - Purpose: train on all features with ARD regularization.
#          - Outputs: saved model `mofa/run_01_only_ARD.hdf5`, R² per view.
#       - Run 2 — Filtered proteins (top variance)
#          - Purpose: reduce proteomics features (e.g., top 2000 by variance) to improve signal / speed.
#          - Outputs: saved model `mofa/run_02_filtered_proteins.hdf5`, R² per view.
#     - 2.2 Comparison & visualization
#       - Load both saved models, compute R² per view, plot stacked variance-per-factor barplots and weight heatmaps to compare view contributions and factor structure.
#
# 3. DIABLO training (optional)
#     - Next: prepare inputs (matched samples across views), tune regularization and components, run cross-validated DIABLO and inspect variable loadings and classification performance.

# %% [markdown]
# ### Step 1. Data Prep

# %%
# Load datasets
proteins = pd.read_csv('data/proteins.csv')
lipids = pd.read_csv('data/lipids.csv')
metabolites = pd.read_csv('data/metabolites.csv')

# Split labels and keep it separately
pro_labels = proteins[proteins['sample'] == 'label'].iloc[0,1:].values
lipid_labels = lipids[lipids['sample'] == 'label'].iloc[0,1:].values
meta_labels = metabolites[metabolites['sample'] == 'label'].iloc[0,1:].values

# Now remove the label row
pro_nolabel = proteins[proteins['sample'] != 'label'].reset_index(drop=True)
lipid_nolabel = lipids[lipids['sample'] != 'label'].reset_index(drop=True)
meta_nolabel = metabolites[metabolites['sample'] != 'label'].reset_index(drop=True)

# Set id_cols as index
pro_nolabel = pro_nolabel.set_index('sample')
lipid_nolabel = lipid_nolabel.set_index('sample')
meta_nolabel = meta_nolabel.set_index('sample')

# %% [markdown]
# ### Step 2. MOFA+ Training

# %%
# ==================== Helper tools ====================
class MOFATrainer:
    """
    One fixed MOFA+ trainer supporting configuration
    """
    def __init__(
        self,
        pro: pd.DataFrame,
        lipid: pd.DataFrame,
        meta: pd.DataFrame,
        labels : np.ndarray,
        views_names = ['proteomics', 'lipidomics', 'metabolomics'],
    ):
        """
        Parameters:
        -----------
        pro : pd.DataFrame
            Proteomics data (samples x features)
        lipid : pd.DataFrame
            Lipidomics data (samples x features)
        meta : pd.DataFrame
            Metabolomics data (samples x features)
        labels : np.ndarray
            Sample class labels (for later analysis, NOT used in MOFA+ training)
        views_names : List[str]
            Names of views 
        """
        # Transpose: features × samples → samples × features
        self.pro = pro.T 
        self.lipid = lipid.T
        self.meta = meta.T
        self.views_names = views_names
        self.pro_labels = pro_labels

        # Store labels separately (NOT used in MOFA+ training)
        self.labels = labels

        # Extract metadata
        pro_features = [f for f in self.pro.columns.tolist()]
        lipid_features = [f for f in self.lipid.columns.tolist()]
        meta_features = [f for f in self.meta.columns.tolist()]

        self.sample_names = self.pro.index.tolist()
        self.group_names = self.pro_labels.tolist()
        self.features_names = [
            pro_features,
            lipid_features,
            meta_features
        ]

        print(f"Initialized trainer:")
        print(f"  Samples: {len(self.sample_names)}")
        print(f"  Proteomics features: {len(pro_features)}")
        print(f"  Lipidomics features: {len(lipid_features)}")
        print(f"  Metabolomics features: {len(meta_features)}")
        if labels is not None:
            print(f"  Labels: {np.unique(labels, return_counts=True)}")
        
    def fit(
        self,
        factors: int = 10,
        seed: int = 2026,
        iterations: int = 1000,
        convergence_mode: str = 'medium',
        dropR2: float = 0.001,
        save_path: Optional[str] = None,
        verbose: bool = False
    ) -> entry_point:
        """
        Train MOFA+ model
        
        Parameters:
        -----------
        factors : int
            Number of latent factors
        seed : int
            Random seed for reproducibility
        iterations : int
            Maximum training iterations
        convergence_mode : str
            'slow', 'medium', or 'fast'
        dropR2: float
            Minimum variance explained criteria to choose relevant factors
        save_path : str or None
            Path to save model (if None, doesn't save)
        verbose : bool
            Print training progress
            
        Returns:
        --------
        ent : entry_point
            Trained MOFA+ model
        """
        # Prepare nested data structure
        data_nested = [
            [self.pro.values],
            [self.lipid.values],
            [self.meta.values]
        ]
        
        # Initialize MOFA+
        ent = entry_point()
                
        # Data options
        ent.set_data_options(
            scale_views=True,   # Scale each view
            scale_groups=False
        )
        
        # Set data
        ent.set_data_matrix(
            data=data_nested,
            views_names=self.views_names,
            groups_names=['group1'],
            samples_names=[self.sample_names],
            features_names=self.features_names
        )
        
        # Configure model
        ent.set_model_options(
            factors=factors,
            spikeslab_weights=True,  # Feature-level sparsity
            ard_factors=True,        # Factor-level sparsity
            ard_weights=True         # View-specific regularization (helps with imbalance)
        )
        
        ent.set_train_options(
            iter=iterations,
            convergence_mode=convergence_mode,
            dropR2=dropR2,
            seed=seed,
            verbose=verbose
        )
        
        # Build and train
        if verbose:
            print("Building model...")
        ent.build()
        
        if verbose:
            print("Training model...")
        ent.run()
        
        # Save if requested
        if save_path is not None:
            ent.save(save_path)
            if verbose:
                print(f"Model saved to {save_path}")
        
        return ent

# %%
# MOFA+ Run 1 (Full data + only ARD)

# Train MOFA+ models 
train1 = MOFATrainer(
    pro_nolabel,
    lipid_nolabel,
    meta_nolabel,
    labels=pro_labels,
    views_names=['proteomics', 'lipidomics', 'metabolomics'],
)

model1 = train1.fit(
        factors=10,
        seed=2026,
        iterations=1000,
        convergence_mode='medium',
        dropR2=0.001,
        save_path='mofa_results/run_01_only_ARD.hdf5',
        verbose=False
)
# Out:
# Initialized trainer:
#   Samples: 10
#   Proteomics features: 7537
#   Lipidomics features: 1029
#   Metabolomics features: 200
#   Labels: (array(['Macula', 'Periphery'], dtype=object), array([5, 5]))
#
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# Scaling views to unit variance...
#
# Successfully loaded view='proteomics' group='group1' with N=10 samples and D=7537 features...
# Successfully loaded view='lipidomics' group='group1' with N=10 samples and D=1029 features...
# Successfully loaded view='metabolomics' group='group1' with N=10 samples and D=200 features...
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: True
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: True
# Likelihoods:
# - View 0 (proteomics): gaussian
# - View 1 (lipidomics): gaussian
# - View 2 (metabolomics): gaussian
#
#
#
# Warning: some group(s) have less than 15 samples, MOFA won't be able to learn meaningful factors for these group(s)...
#
#
#
# ######################################
# ## Training the model with seed 2026 ##
# ######################################
#
#
# ELBO before training: -942909.51
#
# Iteration 1: time=0.06, ELBO=-210975.48, deltaELBO=731934.034 (77.62505578%), Factors=9
# Iteration 2: time=0.12, ELBO=-182339.51, deltaELBO=28635.971 (3.03697972%), Factors=9
# Iteration 3: time=0.13, ELBO=-165558.38, deltaELBO=16781.125 (1.77971749%), Factors=8
# Iteration 4: time=0.06, ELBO=-159234.51, deltaELBO=6323.867 (0.67067588%), Factors=8
# Iteration 5: time=0.05, ELBO=-156058.34, deltaELBO=3176.172 (0.33684803%), Factors=8
# Iteration 6: time=0.05, ELBO=-154328.04, deltaELBO=1730.303 (0.18350684%), Factors=8
# Iteration 7: time=0.05, ELBO=-153301.94, deltaELBO=1026.103 (0.10882303%), Factors=8
# Iteration 8: time=0.05, ELBO=-149775.55, deltaELBO=3526.387 (0.37398992%), Factors=7
# Iteration 9: time=0.04, ELBO=-149338.86, deltaELBO=436.686 (0.04631263%), Factors=7
# Iteration 10: time=0.04, ELBO=-149035.90, deltaELBO=302.964 (0.03213073%), Factors=7
# Iteration 11: time=0.04, ELBO=-148811.16, deltaELBO=224.737 (0.02383437%), Factors=7
# Iteration 12: time=0.04, ELBO=-148636.81, deltaELBO=174.357 (0.01849135%), Factors=7
# Iteration 13: time=0.04, ELBO=-148497.48, deltaELBO=139.323 (0.01477590%), Factors=7
# Iteration 14: time=0.04, ELBO=-148383.33, deltaELBO=114.149 (0.01210608%), Factors=7
# Iteration 15: time=0.04, ELBO=-148287.98, deltaELBO=95.351 (0.01011245%), Factors=7
# Iteration 16: time=0.04, ELBO=-148207.19, deltaELBO=80.792 (0.00856838%), Factors=7
# Iteration 17: time=0.04, ELBO=-148138.33, deltaELBO=68.864 (0.00730331%), Factors=7
# Iteration 18: time=0.04, ELBO=-148079.09, deltaELBO=59.235 (0.00628216%), Factors=7
# Iteration 19: time=0.04, ELBO=-148026.74, deltaELBO=52.354 (0.00555238%), Factors=7
# Iteration 20: time=0.05, ELBO=-147979.30, deltaELBO=47.441 (0.00503132%), Factors=7
# Iteration 21: time=0.04, ELBO=-147935.72, deltaELBO=43.572 (0.00462103%), Factors=7
# Iteration 22: time=0.07, ELBO=-147895.76, deltaELBO=39.967 (0.00423867%), Factors=7
# Iteration 23: time=0.05, ELBO=-147859.50, deltaELBO=36.262 (0.00384581%), Factors=7
# Iteration 24: time=0.04, ELBO=-147826.45, deltaELBO=33.045 (0.00350457%), Factors=7
# Iteration 25: time=0.04, ELBO=-147796.00, deltaELBO=30.455 (0.00322985%), Factors=7
# Iteration 26: time=0.04, ELBO=-147768.33, deltaELBO=27.666 (0.00293416%), Factors=7
# Iteration 27: time=0.04, ELBO=-147743.78, deltaELBO=24.548 (0.00260342%), Factors=7
# Iteration 28: time=0.04, ELBO=-147722.47, deltaELBO=21.313 (0.00226031%), Factors=7
# Iteration 29: time=0.04, ELBO=-147703.70, deltaELBO=18.774 (0.00199106%), Factors=7
# Iteration 30: time=0.04, ELBO=-147686.29, deltaELBO=17.403 (0.00184562%), Factors=7
# Iteration 31: time=0.04, ELBO=-147669.43, deltaELBO=16.861 (0.00178823%), Factors=7
# Iteration 32: time=0.04, ELBO=-147652.93, deltaELBO=16.503 (0.00175020%), Factors=7
# Iteration 33: time=0.04, ELBO=-147637.23, deltaELBO=15.697 (0.00166474%), Factors=7
# Iteration 34: time=0.04, ELBO=-147622.60, deltaELBO=14.636 (0.00155217%), Factors=7
# Iteration 35: time=0.04, ELBO=-147608.60, deltaELBO=13.991 (0.00148384%), Factors=7
# Iteration 36: time=0.04, ELBO=-147594.96, deltaELBO=13.647 (0.00144736%), Factors=7
# Iteration 37: time=0.04, ELBO=-147581.84, deltaELBO=13.117 (0.00139109%), Factors=7
# Iteration 38: time=0.04, ELBO=-147569.26, deltaELBO=12.578 (0.00133401%), Factors=7
# Iteration 39: time=0.04, ELBO=-147557.24, deltaELBO=12.021 (0.00127486%), Factors=7
# Iteration 40: time=0.04, ELBO=-147546.17, deltaELBO=11.068 (0.00117384%), Factors=7
# Iteration 41: time=0.04, ELBO=-147536.15, deltaELBO=10.025 (0.00106317%), Factors=7
# Iteration 42: time=0.04, ELBO=-147526.87, deltaELBO=9.275 (0.00098361%), Factors=7
# Iteration 43: time=0.04, ELBO=-147518.15, deltaELBO=8.729 (0.00092573%), Factors=7
# Iteration 44: time=0.04, ELBO=-147509.81, deltaELBO=8.332 (0.00088364%), Factors=7
# Iteration 45: time=0.04, ELBO=-147501.90, deltaELBO=7.910 (0.00083889%), Factors=7
# Iteration 46: time=0.03, ELBO=-147494.24, deltaELBO=7.663 (0.00081265%), Factors=7
# Iteration 47: time=0.04, ELBO=-147486.71, deltaELBO=7.526 (0.00079817%), Factors=7
# Iteration 48: time=0.04, ELBO=-147479.34, deltaELBO=7.373 (0.00078196%), Factors=7
# Iteration 49: time=0.04, ELBO=-147471.90, deltaELBO=7.445 (0.00078961%), Factors=7
# Iteration 50: time=0.04, ELBO=-127895.40, deltaELBO=19576.499 (2.07617999%), Factors=7
# Iteration 51: time=0.05, ELBO=-127355.91, deltaELBO=539.485 (0.05721489%), Factors=7
# Iteration 52: time=0.05, ELBO=-126941.17, deltaELBO=414.742 (0.04398540%), Factors=7
# Iteration 53: time=0.04, ELBO=-126595.86, deltaELBO=345.307 (0.03662146%), Factors=7
# Iteration 54: time=0.05, ELBO=-126298.58, deltaELBO=297.285 (0.03152845%), Factors=7
# Iteration 55: time=0.05, ELBO=-126033.58, deltaELBO=264.999 (0.02810438%), Factors=7
# Iteration 56: time=0.04, ELBO=-125790.92, deltaELBO=242.663 (0.02573558%), Factors=7
# Iteration 57: time=0.04, ELBO=-125564.78, deltaELBO=226.140 (0.02398324%), Factors=7
# Iteration 58: time=0.05, ELBO=-125351.97, deltaELBO=212.802 (0.02256864%), Factors=7
# Iteration 59: time=0.06, ELBO=-125150.90, deltaELBO=201.075 (0.02132493%), Factors=7
# Iteration 60: time=0.05, ELBO=-124960.63, deltaELBO=190.269 (0.02017889%), Factors=7
# Iteration 61: time=0.05, ELBO=-124780.77, deltaELBO=179.856 (0.01907455%), Factors=7
# Iteration 62: time=0.04, ELBO=-124611.12, deltaELBO=169.656 (0.01799279%), Factors=7
# Iteration 63: time=0.04, ELBO=-124451.25, deltaELBO=159.867 (0.01695460%), Factors=7
# Iteration 64: time=0.04, ELBO=-124300.89, deltaELBO=150.363 (0.01594669%), Factors=7
# Iteration 65: time=0.04, ELBO=-124160.07, deltaELBO=140.816 (0.01493419%), Factors=7
# Iteration 66: time=0.05, ELBO=-124029.06, deltaELBO=131.011 (0.01389437%), Factors=7
# Iteration 67: time=0.04, ELBO=-123908.27, deltaELBO=120.792 (0.01281056%), Factors=7
# Iteration 68: time=0.04, ELBO=-123798.08, deltaELBO=110.186 (0.01168576%), Factors=7
# Iteration 69: time=0.04, ELBO=-123698.67, deltaELBO=99.412 (0.01054315%), Factors=7
# Iteration 70: time=0.04, ELBO=-123609.86, deltaELBO=88.811 (0.00941885%), Factors=7
# Iteration 71: time=0.04, ELBO=-123531.11, deltaELBO=78.750 (0.00835176%), Factors=7
# Iteration 72: time=0.04, ELBO=-123461.65, deltaELBO=69.458 (0.00736632%), Factors=7
# Iteration 73: time=0.04, ELBO=-123400.65, deltaELBO=61.003 (0.00646965%), Factors=7
# Iteration 74: time=0.04, ELBO=-123347.27, deltaELBO=53.385 (0.00566170%), Factors=7
# Iteration 75: time=0.04, ELBO=-123300.66, deltaELBO=46.605 (0.00494271%), Factors=7
# Iteration 76: time=0.04, ELBO=-123259.99, deltaELBO=40.671 (0.00431331%), Factors=7
# Iteration 77: time=0.04, ELBO=-123224.43, deltaELBO=35.561 (0.00377136%), Factors=7
# Iteration 78: time=0.04, ELBO=-123193.22, deltaELBO=31.211 (0.00331008%), Factors=7
# Iteration 79: time=0.04, ELBO=-123165.69, deltaELBO=27.530 (0.00291972%), Factors=7
# Iteration 80: time=0.04, ELBO=-123141.27, deltaELBO=24.421 (0.00258992%), Factors=7
# Iteration 81: time=0.04, ELBO=-123119.48, deltaELBO=21.786 (0.00231050%), Factors=7
# Iteration 82: time=0.04, ELBO=-123099.95, deltaELBO=19.536 (0.00207190%), Factors=7
# Iteration 83: time=0.04, ELBO=-123082.35, deltaELBO=17.595 (0.00186598%), Factors=7
# Iteration 84: time=0.04, ELBO=-123066.45, deltaELBO=15.905 (0.00168681%), Factors=7
# Iteration 85: time=0.04, ELBO=-123052.01, deltaELBO=14.434 (0.00153079%), Factors=7
# Iteration 86: time=0.04, ELBO=-123038.85, deltaELBO=13.164 (0.00139614%), Factors=7
# Iteration 87: time=0.04, ELBO=-123026.76, deltaELBO=12.085 (0.00128163%), Factors=7
# Iteration 88: time=0.04, ELBO=-123015.58, deltaELBO=11.178 (0.00118547%), Factors=7
# Iteration 89: time=0.04, ELBO=-123005.17, deltaELBO=10.418 (0.00110489%), Factors=7
# Iteration 90: time=0.04, ELBO=-122995.39, deltaELBO=9.773 (0.00103647%), Factors=7
# Iteration 91: time=0.04, ELBO=-122986.18, deltaELBO=9.210 (0.00097671%), Factors=7
# Iteration 92: time=0.04, ELBO=-122977.49, deltaELBO=8.699 (0.00092257%), Factors=7
# Iteration 93: time=0.04, ELBO=-122969.27, deltaELBO=8.219 (0.00087167%), Factors=7
# Iteration 94: time=0.05, ELBO=-122961.51, deltaELBO=7.756 (0.00082254%), Factors=7
# Iteration 95: time=0.05, ELBO=-122954.21, deltaELBO=7.305 (0.00077468%), Factors=7
# Iteration 96: time=0.04, ELBO=-122947.34, deltaELBO=6.868 (0.00072840%), Factors=7
# Iteration 97: time=0.04, ELBO=-122940.88, deltaELBO=6.454 (0.00068450%), Factors=7
# Iteration 98: time=0.04, ELBO=-122934.81, deltaELBO=6.069 (0.00064364%), Factors=7
# Iteration 99: time=0.04, ELBO=-122929.10, deltaELBO=5.714 (0.00060601%), Factors=7
# Iteration 100: time=0.04, ELBO=-122923.71, deltaELBO=5.387 (0.00057135%), Factors=7
# Iteration 101: time=0.04, ELBO=-122918.63, deltaELBO=5.086 (0.00053934%), Factors=7
# Iteration 102: time=0.04, ELBO=-122913.82, deltaELBO=4.807 (0.00050985%), Factors=7
# Iteration 103: time=0.04, ELBO=-122909.27, deltaELBO=4.552 (0.00048278%), Factors=7
# Iteration 104: time=0.04, ELBO=-122904.95, deltaELBO=4.317 (0.00045779%), Factors=7
# Iteration 105: time=0.04, ELBO=-122900.86, deltaELBO=4.094 (0.00043423%), Factors=7
# Iteration 106: time=0.04, ELBO=-122896.98, deltaELBO=3.879 (0.00041144%), Factors=7
# Iteration 107: time=0.04, ELBO=-122893.31, deltaELBO=3.668 (0.00038905%), Factors=7
# Iteration 108: time=0.04, ELBO=-122889.85, deltaELBO=3.463 (0.00036726%), Factors=7
# Iteration 109: time=0.05, ELBO=-122886.58, deltaELBO=3.270 (0.00034676%), Factors=7
# Iteration 110: time=0.05, ELBO=-122883.48, deltaELBO=3.096 (0.00032834%), Factors=7
# Iteration 111: time=0.04, ELBO=-122880.53, deltaELBO=2.946 (0.00031243%), Factors=7
# Iteration 112: time=0.04, ELBO=-122877.72, deltaELBO=2.819 (0.00029900%), Factors=7
# Iteration 113: time=0.05, ELBO=-122875.00, deltaELBO=2.713 (0.00028778%), Factors=7
# Iteration 114: time=0.05, ELBO=-122872.38, deltaELBO=2.626 (0.00027847%), Factors=7
# Iteration 115: time=0.05, ELBO=-122869.82, deltaELBO=2.554 (0.00027088%), Factors=7
# Iteration 116: time=0.04, ELBO=-122867.32, deltaELBO=2.498 (0.00026489%), Factors=7
# Iteration 117: time=0.07, ELBO=-122864.87, deltaELBO=2.455 (0.00026035%), Factors=7
# Iteration 118: time=0.04, ELBO=-122862.45, deltaELBO=2.422 (0.00025691%), Factors=7
# Iteration 119: time=0.04, ELBO=-122860.05, deltaELBO=2.395 (0.00025395%), Factors=7
# Iteration 120: time=0.04, ELBO=-122857.69, deltaELBO=2.364 (0.00025066%), Factors=7
# Iteration 121: time=0.04, ELBO=-122855.36, deltaELBO=2.325 (0.00024654%), Factors=7
# Iteration 122: time=0.04, ELBO=-122853.09, deltaELBO=2.279 (0.00024170%), Factors=7
# Iteration 123: time=0.04, ELBO=-122850.85, deltaELBO=2.231 (0.00023666%), Factors=7
# Iteration 124: time=0.04, ELBO=-122848.67, deltaELBO=2.186 (0.00023183%), Factors=7
# Iteration 125: time=0.04, ELBO=-122846.52, deltaELBO=2.144 (0.00022735%), Factors=7
# Iteration 126: time=0.04, ELBO=-122844.42, deltaELBO=2.103 (0.00022304%), Factors=7
# Iteration 127: time=0.04, ELBO=-122842.36, deltaELBO=2.061 (0.00021863%), Factors=7
# Iteration 128: time=0.04, ELBO=-122840.34, deltaELBO=2.017 (0.00021386%), Factors=7
# Iteration 129: time=0.04, ELBO=-122838.38, deltaELBO=1.968 (0.00020874%), Factors=7
# Iteration 130: time=0.04, ELBO=-122836.46, deltaELBO=1.919 (0.00020348%), Factors=7
# Iteration 131: time=0.04, ELBO=-122834.59, deltaELBO=1.871 (0.00019843%), Factors=7
# Iteration 132: time=0.04, ELBO=-122832.76, deltaELBO=1.829 (0.00019396%), Factors=7
# Iteration 133: time=0.04, ELBO=-122830.96, deltaELBO=1.794 (0.00019030%), Factors=7
# Iteration 134: time=0.04, ELBO=-122829.19, deltaELBO=1.769 (0.00018756%), Factors=7
# Iteration 135: time=0.04, ELBO=-122827.44, deltaELBO=1.751 (0.00018573%), Factors=7
# Iteration 136: time=0.04, ELBO=-122825.70, deltaELBO=1.741 (0.00018462%), Factors=7
# Iteration 137: time=0.04, ELBO=-122823.97, deltaELBO=1.735 (0.00018399%), Factors=7
# Iteration 138: time=0.04, ELBO=-122822.24, deltaELBO=1.730 (0.00018350%), Factors=7
# Iteration 139: time=0.04, ELBO=-122820.51, deltaELBO=1.724 (0.00018285%), Factors=7
# Iteration 140: time=0.04, ELBO=-122818.80, deltaELBO=1.714 (0.00018183%), Factors=7
# Iteration 141: time=0.04, ELBO=-122817.10, deltaELBO=1.701 (0.00018036%), Factors=7
# Iteration 142: time=0.04, ELBO=-122815.41, deltaELBO=1.683 (0.00017850%), Factors=7
# Iteration 143: time=0.04, ELBO=-122813.75, deltaELBO=1.663 (0.00017633%), Factors=7
# Iteration 144: time=0.04, ELBO=-122812.11, deltaELBO=1.640 (0.00017395%), Factors=7
# Iteration 145: time=0.04, ELBO=-122810.50, deltaELBO=1.616 (0.00017142%), Factors=7
# Iteration 146: time=0.04, ELBO=-122808.90, deltaELBO=1.591 (0.00016869%), Factors=7
# Iteration 147: time=0.05, ELBO=-122807.34, deltaELBO=1.562 (0.00016571%), Factors=7
# Iteration 148: time=0.04, ELBO=-122805.81, deltaELBO=1.531 (0.00016240%), Factors=7
# Iteration 149: time=0.04, ELBO=-122804.31, deltaELBO=1.497 (0.00015879%), Factors=7
# Iteration 150: time=0.04, ELBO=-122802.85, deltaELBO=1.461 (0.00015495%), Factors=7
# Iteration 151: time=0.04, ELBO=-122801.43, deltaELBO=1.424 (0.00015103%), Factors=7
# Iteration 152: time=0.04, ELBO=-122800.04, deltaELBO=1.387 (0.00014712%), Factors=7
# Iteration 153: time=0.04, ELBO=-122798.69, deltaELBO=1.351 (0.00014332%), Factors=7
# Iteration 154: time=0.04, ELBO=-122797.37, deltaELBO=1.317 (0.00013972%), Factors=7
# Iteration 155: time=0.04, ELBO=-122796.09, deltaELBO=1.286 (0.00013640%), Factors=7
# Iteration 156: time=0.04, ELBO=-122794.83, deltaELBO=1.258 (0.00013341%), Factors=7
# Iteration 157: time=0.05, ELBO=-122793.60, deltaELBO=1.233 (0.00013075%), Factors=7
# Iteration 158: time=0.05, ELBO=-122792.38, deltaELBO=1.211 (0.00012838%), Factors=7
# Iteration 159: time=0.04, ELBO=-122791.19, deltaELBO=1.190 (0.00012620%), Factors=7
# Iteration 160: time=0.05, ELBO=-122790.02, deltaELBO=1.170 (0.00012411%), Factors=7
# Iteration 161: time=0.05, ELBO=-122788.87, deltaELBO=1.150 (0.00012201%), Factors=7
# Iteration 162: time=0.04, ELBO=-122787.74, deltaELBO=1.130 (0.00011986%), Factors=7
# Iteration 163: time=0.04, ELBO=-122786.63, deltaELBO=1.109 (0.00011763%), Factors=7
# Iteration 164: time=0.05, ELBO=-122785.55, deltaELBO=1.087 (0.00011531%), Factors=7
# Iteration 165: time=0.07, ELBO=-122784.48, deltaELBO=1.065 (0.00011294%), Factors=7
# Iteration 166: time=0.04, ELBO=-122783.44, deltaELBO=1.043 (0.00011056%), Factors=7
# Iteration 167: time=0.04, ELBO=-122782.42, deltaELBO=1.021 (0.00010825%), Factors=7
# Iteration 168: time=0.04, ELBO=-122781.42, deltaELBO=1.000 (0.00010606%), Factors=7
# Iteration 169: time=0.04, ELBO=-122780.44, deltaELBO=0.981 (0.00010402%), Factors=7
# Iteration 170: time=0.04, ELBO=-122779.48, deltaELBO=0.963 (0.00010217%), Factors=7
# Iteration 171: time=0.04, ELBO=-122778.53, deltaELBO=0.948 (0.00010049%), Factors=7
# Iteration 172: time=0.04, ELBO=-122777.59, deltaELBO=0.933 (0.00009895%), Factors=7
# Iteration 173: time=0.04, ELBO=-122776.68, deltaELBO=0.919 (0.00009750%), Factors=7
# Iteration 174: time=0.04, ELBO=-122775.77, deltaELBO=0.906 (0.00009609%), Factors=7
# Iteration 175: time=0.04, ELBO=-122774.88, deltaELBO=0.893 (0.00009467%), Factors=7
# Iteration 176: time=0.04, ELBO=-122774.00, deltaELBO=0.879 (0.00009324%), Factors=7
# Iteration 177: time=0.04, ELBO=-122773.13, deltaELBO=0.866 (0.00009180%), Factors=7
# Iteration 178: time=0.04, ELBO=-122772.28, deltaELBO=0.852 (0.00009037%), Factors=7
# Iteration 179: time=0.04, ELBO=-122771.44, deltaELBO=0.839 (0.00008898%), Factors=7
# Iteration 180: time=0.04, ELBO=-122770.61, deltaELBO=0.827 (0.00008767%), Factors=7
# Iteration 181: time=0.04, ELBO=-122769.80, deltaELBO=0.815 (0.00008647%), Factors=7
# Iteration 182: time=0.04, ELBO=-122768.99, deltaELBO=0.805 (0.00008537%), Factors=7
# Iteration 183: time=0.04, ELBO=-122768.20, deltaELBO=0.796 (0.00008438%), Factors=7
# Iteration 184: time=0.04, ELBO=-122767.41, deltaELBO=0.787 (0.00008349%), Factors=7
# Iteration 185: time=0.04, ELBO=-122766.63, deltaELBO=0.779 (0.00008267%), Factors=7
# Iteration 186: time=0.04, ELBO=-122765.86, deltaELBO=0.772 (0.00008190%), Factors=7
# Iteration 187: time=0.04, ELBO=-122765.09, deltaELBO=0.765 (0.00008117%), Factors=7
# Iteration 188: time=0.04, ELBO=-122764.34, deltaELBO=0.758 (0.00008044%), Factors=7
# Iteration 189: time=0.04, ELBO=-122763.58, deltaELBO=0.752 (0.00007971%), Factors=7
# Iteration 190: time=0.04, ELBO=-122762.84, deltaELBO=0.744 (0.00007894%), Factors=7
# Iteration 191: time=0.04, ELBO=-122762.10, deltaELBO=0.737 (0.00007814%), Factors=7
# Iteration 192: time=0.04, ELBO=-122761.37, deltaELBO=0.729 (0.00007729%), Factors=7
# Iteration 193: time=0.04, ELBO=-122760.65, deltaELBO=0.720 (0.00007638%), Factors=7
# Iteration 194: time=0.05, ELBO=-122759.94, deltaELBO=0.711 (0.00007542%), Factors=7
# Iteration 195: time=0.05, ELBO=-122759.24, deltaELBO=0.702 (0.00007442%), Factors=7
# Iteration 196: time=0.04, ELBO=-122758.55, deltaELBO=0.692 (0.00007340%), Factors=7
# Iteration 197: time=0.05, ELBO=-122757.87, deltaELBO=0.682 (0.00007238%), Factors=7
# Iteration 198: time=0.04, ELBO=-122757.19, deltaELBO=0.673 (0.00007137%), Factors=7
# Iteration 199: time=0.04, ELBO=-122756.53, deltaELBO=0.664 (0.00007038%), Factors=7
# Iteration 200: time=0.05, ELBO=-122755.88, deltaELBO=0.655 (0.00006943%), Factors=7
# Iteration 201: time=0.04, ELBO=-122755.23, deltaELBO=0.646 (0.00006852%), Factors=7
# Iteration 202: time=0.08, ELBO=-122754.59, deltaELBO=0.638 (0.00006765%), Factors=7
# Iteration 203: time=0.04, ELBO=-122753.96, deltaELBO=0.630 (0.00006681%), Factors=7
# Iteration 204: time=0.04, ELBO=-122753.34, deltaELBO=0.622 (0.00006598%), Factors=7
# Iteration 205: time=0.04, ELBO=-122752.72, deltaELBO=0.615 (0.00006518%), Factors=7
# Iteration 206: time=0.04, ELBO=-122752.12, deltaELBO=0.607 (0.00006437%), Factors=7
# Iteration 207: time=0.04, ELBO=-122751.52, deltaELBO=0.599 (0.00006357%), Factors=7
# Iteration 208: time=0.04, ELBO=-122750.93, deltaELBO=0.592 (0.00006277%), Factors=7
# Iteration 209: time=0.04, ELBO=-122750.34, deltaELBO=0.584 (0.00006197%), Factors=7
# Iteration 210: time=0.04, ELBO=-122749.76, deltaELBO=0.577 (0.00006118%), Factors=7
# Iteration 211: time=0.04, ELBO=-122749.20, deltaELBO=0.570 (0.00006041%), Factors=7
# Iteration 212: time=0.05, ELBO=-122748.63, deltaELBO=0.562 (0.00005966%), Factors=7
# Iteration 213: time=0.04, ELBO=-122748.08, deltaELBO=0.556 (0.00005894%), Factors=7
# Iteration 214: time=0.04, ELBO=-122747.53, deltaELBO=0.549 (0.00005825%), Factors=7
# Iteration 215: time=0.04, ELBO=-122746.98, deltaELBO=0.543 (0.00005761%), Factors=7
# Iteration 216: time=0.04, ELBO=-122746.45, deltaELBO=0.537 (0.00005700%), Factors=7
# Iteration 217: time=0.04, ELBO=-122745.92, deltaELBO=0.532 (0.00005643%), Factors=7
# Iteration 218: time=0.04, ELBO=-122745.39, deltaELBO=0.527 (0.00005591%), Factors=7
# Iteration 219: time=0.04, ELBO=-122744.87, deltaELBO=0.522 (0.00005541%), Factors=7
# Iteration 220: time=0.04, ELBO=-122744.35, deltaELBO=0.518 (0.00005494%), Factors=7
# Iteration 221: time=0.04, ELBO=-122743.83, deltaELBO=0.514 (0.00005450%), Factors=7
# Iteration 222: time=0.04, ELBO=-122743.32, deltaELBO=0.510 (0.00005408%), Factors=7
# Iteration 223: time=0.04, ELBO=-122742.82, deltaELBO=0.506 (0.00005367%), Factors=7
# Iteration 224: time=0.04, ELBO=-122742.32, deltaELBO=0.502 (0.00005327%), Factors=7
# Iteration 225: time=0.04, ELBO=-122741.82, deltaELBO=0.499 (0.00005289%), Factors=7
# Iteration 226: time=0.04, ELBO=-122741.32, deltaELBO=0.495 (0.00005253%), Factors=7
# Iteration 227: time=0.04, ELBO=-122740.83, deltaELBO=0.492 (0.00005218%), Factors=7
# Iteration 228: time=0.04, ELBO=-122740.34, deltaELBO=0.489 (0.00005187%), Factors=7
# Iteration 229: time=0.04, ELBO=-122739.85, deltaELBO=0.487 (0.00005161%), Factors=7
# Iteration 230: time=0.04, ELBO=-122739.37, deltaELBO=0.485 (0.00005142%), Factors=7
# Iteration 231: time=0.04, ELBO=-122738.88, deltaELBO=0.484 (0.00005132%), Factors=7
# Iteration 232: time=0.04, ELBO=-122738.40, deltaELBO=0.484 (0.00005132%), Factors=7
# Iteration 233: time=0.04, ELBO=-122737.92, deltaELBO=0.485 (0.00005145%), Factors=7
# Iteration 234: time=0.04, ELBO=-122737.43, deltaELBO=0.488 (0.00005171%), Factors=7
# Iteration 235: time=0.05, ELBO=-122736.94, deltaELBO=0.491 (0.00005209%), Factors=7
# Iteration 236: time=0.05, ELBO=-122736.44, deltaELBO=0.496 (0.00005258%), Factors=7
# Iteration 237: time=0.04, ELBO=-122735.94, deltaELBO=0.501 (0.00005312%), Factors=7
# Iteration 238: time=0.05, ELBO=-122735.43, deltaELBO=0.506 (0.00005365%), Factors=7
# Iteration 239: time=0.05, ELBO=-122734.92, deltaELBO=0.510 (0.00005411%), Factors=7
# Iteration 240: time=0.07, ELBO=-122734.41, deltaELBO=0.513 (0.00005441%), Factors=7
# Iteration 241: time=0.04, ELBO=-122733.90, deltaELBO=0.514 (0.00005450%), Factors=7
# Iteration 242: time=0.04, ELBO=-122733.39, deltaELBO=0.512 (0.00005434%), Factors=7
# Iteration 243: time=0.04, ELBO=-122732.88, deltaELBO=0.508 (0.00005389%), Factors=7
# Iteration 244: time=0.04, ELBO=-122732.38, deltaELBO=0.501 (0.00005317%), Factors=7
# Iteration 245: time=0.04, ELBO=-122731.88, deltaELBO=0.492 (0.00005222%), Factors=7
# Iteration 246: time=0.04, ELBO=-122731.40, deltaELBO=0.482 (0.00005110%), Factors=7
# Iteration 247: time=0.04, ELBO=-122730.93, deltaELBO=0.470 (0.00004987%), Factors=7
# Iteration 248: time=0.04, ELBO=-122730.47, deltaELBO=0.458 (0.00004861%), Factors=7
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################
#
#
# Output directory does not exist, creating it...
# Saving model in mofa_results/run_01_only_ARD.hdf5...

# %%
# MOFA+ Run 2 (Filtered proteins + ARD)

# Filter proteins
pro_nolabel = pro_nolabel.apply(pd.to_numeric, errors='coerce') # Force all values to be numeric in case they are still strings
pro_var = pro_nolabel.var(axis=1)
top_proteins = (pro_var.nlargest(min(2000, len(pro_var))).index)
pro_nolabel_filtered = pro_nolabel.loc[top_proteins]

# Train model
train2 = MOFATrainer(
    pro_nolabel_filtered,
    lipid_nolabel,
    meta_nolabel,
    labels=pro_labels,
    views_names=['proteomics', 'lipidomics', 'metabolomics'],
)

model2 = train2.fit(
        factors=10,
        seed=2026,
        iterations=1000,
        convergence_mode='medium',
        dropR2=0.001,
        save_path='mofa_results/run_02_filtered_proteins.hdf5',
        verbose=False
)
# Out:
# Initialized trainer:
#   Samples: 10
#   Proteomics features: 2000
#   Lipidomics features: 1029
#   Metabolomics features: 200
#   Labels: (array(['Macula', 'Periphery'], dtype=object), array([5, 5]))
#
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# Scaling views to unit variance...
#
# Successfully loaded view='proteomics' group='group1' with N=10 samples and D=2000 features...
# Successfully loaded view='lipidomics' group='group1' with N=10 samples and D=1029 features...
# Successfully loaded view='metabolomics' group='group1' with N=10 samples and D=200 features...
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: True
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: True
# Likelihoods:
# - View 0 (proteomics): gaussian
# - View 1 (lipidomics): gaussian
# - View 2 (metabolomics): gaussian
#
#
#
# Warning: some group(s) have less than 15 samples, MOFA won't be able to learn meaningful factors for these group(s)...
#
#
#
# ######################################
# ## Training the model with seed 2026 ##
# ######################################
#
#
# ELBO before training: -346384.44
#
# Iteration 1: time=0.03, ELBO=-84099.64, deltaELBO=262284.796 (75.72072127%), Factors=9
# Iteration 2: time=0.02, ELBO=-74103.45, deltaELBO=9996.197 (2.88586792%), Factors=9
# Iteration 3: time=0.02, ELBO=-69681.78, deltaELBO=4421.664 (1.27651933%), Factors=9
# Iteration 4: time=0.02, ELBO=-66822.57, deltaELBO=2859.211 (0.82544431%), Factors=8
# Iteration 5: time=0.02, ELBO=-65989.56, deltaELBO=833.011 (0.24048753%), Factors=8
# Iteration 6: time=0.02, ELBO=-65602.95, deltaELBO=386.613 (0.11161378%), Factors=8
# Iteration 7: time=0.02, ELBO=-64204.14, deltaELBO=1398.807 (0.40383078%), Factors=7
# Iteration 8: time=0.02, ELBO=-63995.18, deltaELBO=208.963 (0.06032704%), Factors=7
# Iteration 9: time=0.02, ELBO=-63806.45, deltaELBO=188.731 (0.05448608%), Factors=7
# Iteration 10: time=0.02, ELBO=-63637.26, deltaELBO=169.181 (0.04884192%), Factors=7
# Iteration 11: time=0.02, ELBO=-63488.36, deltaELBO=148.900 (0.04298698%), Factors=7
# Iteration 12: time=0.02, ELBO=-63360.68, deltaELBO=127.681 (0.03686104%), Factors=7
# Iteration 13: time=0.02, ELBO=-63254.86, deltaELBO=105.819 (0.03054964%), Factors=7
# Iteration 14: time=0.02, ELBO=-63167.67, deltaELBO=87.192 (0.02517191%), Factors=7
# Iteration 15: time=0.02, ELBO=-63094.45, deltaELBO=73.223 (0.02113937%), Factors=7
# Iteration 16: time=0.02, ELBO=-63032.95, deltaELBO=61.498 (0.01775414%), Factors=7
# Iteration 17: time=0.02, ELBO=-62981.10, deltaELBO=51.853 (0.01496988%), Factors=7
# Iteration 18: time=0.02, ELBO=-62936.49, deltaELBO=44.611 (0.01287900%), Factors=7
# Iteration 19: time=0.02, ELBO=-62897.14, deltaELBO=39.350 (0.01136012%), Factors=7
# Iteration 20: time=0.03, ELBO=-62861.90, deltaELBO=35.234 (0.01017195%), Factors=7
# Iteration 21: time=0.02, ELBO=-62830.43, deltaELBO=31.475 (0.00908663%), Factors=7
# Iteration 22: time=0.02, ELBO=-62802.27, deltaELBO=28.155 (0.00812827%), Factors=7
# Iteration 23: time=0.02, ELBO=-62777.17, deltaELBO=25.104 (0.00724736%), Factors=7
# Iteration 24: time=0.02, ELBO=-62754.97, deltaELBO=22.201 (0.00640921%), Factors=7
# Iteration 25: time=0.02, ELBO=-62735.51, deltaELBO=19.463 (0.00561888%), Factors=7
# Iteration 26: time=0.02, ELBO=-62718.34, deltaELBO=17.162 (0.00495462%), Factors=7
# Iteration 27: time=0.02, ELBO=-62702.91, deltaELBO=15.434 (0.00445568%), Factors=7
# Iteration 28: time=0.02, ELBO=-62688.91, deltaELBO=13.999 (0.00404145%), Factors=7
# Iteration 29: time=0.02, ELBO=-62676.06, deltaELBO=12.852 (0.00371033%), Factors=7
# Iteration 30: time=0.02, ELBO=-62663.86, deltaELBO=12.202 (0.00352279%), Factors=7
# Iteration 31: time=0.02, ELBO=-62651.76, deltaELBO=12.096 (0.00349220%), Factors=7
# Iteration 32: time=0.02, ELBO=-62639.70, deltaELBO=12.062 (0.00348223%), Factors=7
# Iteration 33: time=0.02, ELBO=-62628.23, deltaELBO=11.473 (0.00331232%), Factors=7
# Iteration 34: time=0.02, ELBO=-62617.71, deltaELBO=10.520 (0.00303709%), Factors=7
# Iteration 35: time=0.02, ELBO=-62608.09, deltaELBO=9.614 (0.00277540%), Factors=7
# Iteration 36: time=0.02, ELBO=-62598.98, deltaELBO=9.107 (0.00262927%), Factors=7
# Iteration 37: time=0.02, ELBO=-62590.19, deltaELBO=8.798 (0.00254002%), Factors=7
# Iteration 38: time=0.02, ELBO=-62581.82, deltaELBO=8.365 (0.00241487%), Factors=7
# Iteration 39: time=0.02, ELBO=-62573.99, deltaELBO=7.827 (0.00225966%), Factors=7
# Iteration 40: time=0.02, ELBO=-62566.78, deltaELBO=7.217 (0.00208352%), Factors=7
# Iteration 41: time=0.02, ELBO=-62560.26, deltaELBO=6.515 (0.00188075%), Factors=7
# Iteration 42: time=0.02, ELBO=-62554.48, deltaELBO=5.782 (0.00166910%), Factors=7
# Iteration 43: time=0.02, ELBO=-62549.31, deltaELBO=5.169 (0.00149241%), Factors=7
# Iteration 44: time=0.02, ELBO=-62544.47, deltaELBO=4.845 (0.00139887%), Factors=7
# Iteration 45: time=0.02, ELBO=-62539.76, deltaELBO=4.702 (0.00135753%), Factors=7
# Iteration 46: time=0.02, ELBO=-62535.26, deltaELBO=4.503 (0.00130004%), Factors=7
# Iteration 47: time=0.02, ELBO=-62531.03, deltaELBO=4.232 (0.00122176%), Factors=7
# Iteration 48: time=0.02, ELBO=-62527.02, deltaELBO=4.007 (0.00115673%), Factors=7
# Iteration 49: time=0.02, ELBO=-62523.21, deltaELBO=3.816 (0.00110160%), Factors=7
# Iteration 50: time=0.02, ELBO=-55285.14, deltaELBO=7238.067 (2.08960507%), Factors=7
# Iteration 51: time=0.02, ELBO=-55049.29, deltaELBO=235.852 (0.06808963%), Factors=7
# Iteration 52: time=0.02, ELBO=-54888.64, deltaELBO=160.647 (0.04637838%), Factors=7
# Iteration 53: time=0.02, ELBO=-54768.39, deltaELBO=120.254 (0.03471702%), Factors=7
# Iteration 54: time=0.02, ELBO=-54673.68, deltaELBO=94.705 (0.02734101%), Factors=7
# Iteration 55: time=0.02, ELBO=-54595.40, deltaELBO=78.284 (0.02260040%), Factors=7
# Iteration 56: time=0.02, ELBO=-54528.02, deltaELBO=67.373 (0.01945041%), Factors=7
# Iteration 57: time=0.02, ELBO=-54468.24, deltaELBO=59.787 (0.01726036%), Factors=7
# Iteration 58: time=0.02, ELBO=-54413.92, deltaELBO=54.316 (0.01568075%), Factors=7
# Iteration 59: time=0.02, ELBO=-54363.58, deltaELBO=50.339 (0.01453260%), Factors=7
# Iteration 60: time=0.02, ELBO=-54316.13, deltaELBO=47.450 (0.01369858%), Factors=7
# Iteration 61: time=0.02, ELBO=-54270.87, deltaELBO=45.259 (0.01306611%), Factors=7
# Iteration 62: time=0.02, ELBO=-54227.51, deltaELBO=43.359 (0.01251768%), Factors=7
# Iteration 63: time=0.02, ELBO=-54186.06, deltaELBO=41.457 (0.01196850%), Factors=7
# Iteration 64: time=0.02, ELBO=-54146.52, deltaELBO=39.533 (0.01141310%), Factors=7
# Iteration 65: time=0.02, ELBO=-54108.91, deltaELBO=37.613 (0.01085877%), Factors=7
# Iteration 66: time=0.02, ELBO=-54073.30, deltaELBO=35.613 (0.01028141%), Factors=7
# Iteration 67: time=0.02, ELBO=-54039.80, deltaELBO=33.498 (0.00967085%), Factors=7
# Iteration 68: time=0.02, ELBO=-54008.53, deltaELBO=31.266 (0.00902635%), Factors=7
# Iteration 69: time=0.02, ELBO=-53979.64, deltaELBO=28.896 (0.00834213%), Factors=7
# Iteration 70: time=0.02, ELBO=-53953.14, deltaELBO=26.497 (0.00764968%), Factors=7
# Iteration 71: time=0.02, ELBO=-53928.95, deltaELBO=24.186 (0.00698253%), Factors=7
# Iteration 72: time=0.02, ELBO=-53906.98, deltaELBO=21.979 (0.00634514%), Factors=7
# Iteration 73: time=0.02, ELBO=-53887.13, deltaELBO=19.847 (0.00572988%), Factors=7
# Iteration 74: time=0.02, ELBO=-53869.33, deltaELBO=17.801 (0.00513903%), Factors=7
# Iteration 75: time=0.02, ELBO=-53853.44, deltaELBO=15.890 (0.00458745%), Factors=7
# Iteration 76: time=0.02, ELBO=-53839.27, deltaELBO=14.168 (0.00409019%), Factors=7
# Iteration 77: time=0.02, ELBO=-53826.60, deltaELBO=12.668 (0.00365716%), Factors=7
# Iteration 78: time=0.02, ELBO=-53815.19, deltaELBO=11.409 (0.00329360%), Factors=7
# Iteration 79: time=0.02, ELBO=-53804.81, deltaELBO=10.384 (0.00299787%), Factors=7
# Iteration 80: time=0.02, ELBO=-53795.26, deltaELBO=9.553 (0.00275780%), Factors=7
# Iteration 81: time=0.02, ELBO=-53786.42, deltaELBO=8.837 (0.00255126%), Factors=7
# Iteration 82: time=0.02, ELBO=-53778.25, deltaELBO=8.165 (0.00235720%), Factors=7
# Iteration 83: time=0.02, ELBO=-53770.74, deltaELBO=7.510 (0.00216822%), Factors=7
# Iteration 84: time=0.02, ELBO=-53763.86, deltaELBO=6.887 (0.00198832%), Factors=7
# Iteration 85: time=0.02, ELBO=-53757.54, deltaELBO=6.316 (0.00182330%), Factors=7
# Iteration 86: time=0.02, ELBO=-53751.73, deltaELBO=5.806 (0.00167625%), Factors=7
# Iteration 87: time=0.02, ELBO=-53746.37, deltaELBO=5.360 (0.00154735%), Factors=7
# Iteration 88: time=0.02, ELBO=-53741.40, deltaELBO=4.970 (0.00143483%), Factors=7
# Iteration 89: time=0.02, ELBO=-53736.78, deltaELBO=4.622 (0.00133445%), Factors=7
# Iteration 90: time=0.02, ELBO=-53732.48, deltaELBO=4.298 (0.00124076%), Factors=7
# Iteration 91: time=0.02, ELBO=-53728.49, deltaELBO=3.990 (0.00115178%), Factors=7
# Iteration 92: time=0.02, ELBO=-53724.79, deltaELBO=3.710 (0.00107094%), Factors=7
# Iteration 93: time=0.02, ELBO=-53721.31, deltaELBO=3.474 (0.00100287%), Factors=7
# Iteration 94: time=0.02, ELBO=-53718.02, deltaELBO=3.287 (0.00094897%), Factors=7
# Iteration 95: time=0.02, ELBO=-53714.88, deltaELBO=3.141 (0.00090685%), Factors=7
# Iteration 96: time=0.02, ELBO=-53711.86, deltaELBO=3.021 (0.00087205%), Factors=7
# Iteration 97: time=0.02, ELBO=-53708.95, deltaELBO=2.909 (0.00083981%), Factors=7
# Iteration 98: time=0.02, ELBO=-53706.16, deltaELBO=2.794 (0.00080661%), Factors=7
# Iteration 99: time=0.02, ELBO=-53703.49, deltaELBO=2.671 (0.00077117%), Factors=7
# Iteration 100: time=0.02, ELBO=-53700.95, deltaELBO=2.543 (0.00073418%), Factors=7
# Iteration 101: time=0.02, ELBO=-53698.53, deltaELBO=2.415 (0.00069723%), Factors=7
# Iteration 102: time=0.02, ELBO=-53696.24, deltaELBO=2.294 (0.00066236%), Factors=7
# Iteration 103: time=0.02, ELBO=-53694.05, deltaELBO=2.189 (0.00063191%), Factors=7
# Iteration 104: time=0.02, ELBO=-53691.94, deltaELBO=2.106 (0.00060812%), Factors=7
# Iteration 105: time=0.02, ELBO=-53689.89, deltaELBO=2.052 (0.00059249%), Factors=7
# Iteration 106: time=0.02, ELBO=-53687.86, deltaELBO=2.027 (0.00058522%), Factors=7
# Iteration 107: time=0.02, ELBO=-53685.83, deltaELBO=2.026 (0.00058503%), Factors=7
# Iteration 108: time=0.02, ELBO=-53683.79, deltaELBO=2.041 (0.00058924%), Factors=7
# Iteration 109: time=0.02, ELBO=-53681.74, deltaELBO=2.058 (0.00059404%), Factors=7
# Iteration 110: time=0.02, ELBO=-53679.67, deltaELBO=2.062 (0.00059523%), Factors=7
# Iteration 111: time=0.02, ELBO=-53677.63, deltaELBO=2.041 (0.00058912%), Factors=7
# Iteration 112: time=0.02, ELBO=-53675.65, deltaELBO=1.987 (0.00057350%), Factors=7
# Iteration 113: time=0.02, ELBO=-53673.75, deltaELBO=1.899 (0.00054834%), Factors=7
# Iteration 114: time=0.02, ELBO=-53671.96, deltaELBO=1.785 (0.00051543%), Factors=7
# Iteration 115: time=0.02, ELBO=-53670.31, deltaELBO=1.653 (0.00047726%), Factors=7
# Iteration 116: time=0.02, ELBO=-53668.80, deltaELBO=1.512 (0.00043657%), Factors=7
# Iteration 117: time=0.02, ELBO=-53667.42, deltaELBO=1.374 (0.00039668%), Factors=7
# Iteration 118: time=0.02, ELBO=-53666.17, deltaELBO=1.251 (0.00036114%), Factors=7
# Iteration 119: time=0.02, ELBO=-53665.02, deltaELBO=1.153 (0.00033282%), Factors=7
# Iteration 120: time=0.02, ELBO=-53663.93, deltaELBO=1.084 (0.00031305%), Factors=7
# Iteration 121: time=0.02, ELBO=-53662.89, deltaELBO=1.044 (0.00030132%), Factors=7
# Iteration 122: time=0.02, ELBO=-53661.87, deltaELBO=1.024 (0.00029549%), Factors=7
# Iteration 123: time=0.02, ELBO=-53660.85, deltaELBO=1.014 (0.00029278%), Factors=7
# Iteration 124: time=0.02, ELBO=-53659.85, deltaELBO=1.008 (0.00029094%), Factors=7
# Iteration 125: time=0.02, ELBO=-53658.85, deltaELBO=1.000 (0.00028863%), Factors=7
# Iteration 126: time=0.02, ELBO=-53657.86, deltaELBO=0.988 (0.00028519%), Factors=7
# Iteration 127: time=0.02, ELBO=-53656.89, deltaELBO=0.971 (0.00028045%), Factors=7
# Iteration 128: time=0.02, ELBO=-53655.94, deltaELBO=0.951 (0.00027467%), Factors=7
# Iteration 129: time=0.02, ELBO=-53655.01, deltaELBO=0.930 (0.00026849%), Factors=7
# Iteration 130: time=0.02, ELBO=-53654.10, deltaELBO=0.910 (0.00026263%), Factors=7
# Iteration 131: time=0.02, ELBO=-53653.20, deltaELBO=0.892 (0.00025752%), Factors=7
# Iteration 132: time=0.02, ELBO=-53652.33, deltaELBO=0.876 (0.00025295%), Factors=7
# Iteration 133: time=0.02, ELBO=-53651.47, deltaELBO=0.859 (0.00024802%), Factors=7
# Iteration 134: time=0.02, ELBO=-53650.63, deltaELBO=0.837 (0.00024150%), Factors=7
# Iteration 135: time=0.02, ELBO=-53649.83, deltaELBO=0.806 (0.00023259%), Factors=7
# Iteration 136: time=0.02, ELBO=-53649.06, deltaELBO=0.768 (0.00022163%), Factors=7
# Iteration 137: time=0.02, ELBO=-53648.33, deltaELBO=0.728 (0.00021009%), Factors=7
# Iteration 138: time=0.02, ELBO=-53647.64, deltaELBO=0.692 (0.00019991%), Factors=7
# Iteration 139: time=0.02, ELBO=-53646.97, deltaELBO=0.667 (0.00019266%), Factors=7
# Iteration 140: time=0.02, ELBO=-53646.32, deltaELBO=0.654 (0.00018894%), Factors=7
# Iteration 141: time=0.02, ELBO=-53645.67, deltaELBO=0.651 (0.00018803%), Factors=7
# Iteration 142: time=0.02, ELBO=-53645.01, deltaELBO=0.652 (0.00018815%), Factors=7
# Iteration 143: time=0.02, ELBO=-53644.36, deltaELBO=0.649 (0.00018745%), Factors=7
# Iteration 144: time=0.02, ELBO=-53643.72, deltaELBO=0.642 (0.00018521%), Factors=7
# Iteration 145: time=0.02, ELBO=-53643.09, deltaELBO=0.630 (0.00018183%), Factors=7
# Iteration 146: time=0.02, ELBO=-53642.48, deltaELBO=0.617 (0.00017799%), Factors=7
# Iteration 147: time=0.02, ELBO=-53641.87, deltaELBO=0.602 (0.00017393%), Factors=7
# Iteration 148: time=0.02, ELBO=-53641.29, deltaELBO=0.587 (0.00016944%), Factors=7
# Iteration 149: time=0.02, ELBO=-53640.72, deltaELBO=0.569 (0.00016415%), Factors=7
# Iteration 150: time=0.02, ELBO=-53640.17, deltaELBO=0.547 (0.00015790%), Factors=7
# Iteration 151: time=0.02, ELBO=-53639.65, deltaELBO=0.523 (0.00015087%), Factors=7
# Iteration 152: time=0.02, ELBO=-53639.15, deltaELBO=0.498 (0.00014367%), Factors=7
# Iteration 153: time=0.02, ELBO=-53638.68, deltaELBO=0.475 (0.00013718%), Factors=7
# Iteration 154: time=0.02, ELBO=-53638.22, deltaELBO=0.459 (0.00013242%), Factors=7
# Iteration 155: time=0.02, ELBO=-53637.77, deltaELBO=0.451 (0.00013031%), Factors=7
# Iteration 156: time=0.02, ELBO=-53637.31, deltaELBO=0.456 (0.00013171%), Factors=7
# Iteration 157: time=0.02, ELBO=-53636.83, deltaELBO=0.476 (0.00013734%), Factors=7
# Iteration 158: time=0.02, ELBO=-53636.32, deltaELBO=0.510 (0.00014723%), Factors=7
# Iteration 159: time=0.02, ELBO=-53635.77, deltaELBO=0.552 (0.00015938%), Factors=7
# Iteration 160: time=0.02, ELBO=-53635.19, deltaELBO=0.585 (0.00016903%), Factors=7
# Iteration 161: time=0.02, ELBO=-53634.59, deltaELBO=0.595 (0.00017163%), Factors=7
# Iteration 162: time=0.02, ELBO=-53634.02, deltaELBO=0.577 (0.00016644%), Factors=7
# Iteration 163: time=0.02, ELBO=-53633.48, deltaELBO=0.537 (0.00015506%), Factors=7
# Iteration 164: time=0.02, ELBO=-53632.99, deltaELBO=0.484 (0.00013959%), Factors=7
# Iteration 165: time=0.02, ELBO=-53632.57, deltaELBO=0.425 (0.00012259%), Factors=7
# Iteration 166: time=0.02, ELBO=-53632.20, deltaELBO=0.370 (0.00010673%), Factors=7
# Iteration 167: time=0.02, ELBO=-53631.88, deltaELBO=0.325 (0.00009382%), Factors=7
# Iteration 168: time=0.02, ELBO=-53631.58, deltaELBO=0.292 (0.00008444%), Factors=7
# Iteration 169: time=0.02, ELBO=-53631.31, deltaELBO=0.271 (0.00007813%), Factors=7
# Iteration 170: time=0.02, ELBO=-53631.06, deltaELBO=0.256 (0.00007405%), Factors=7
# Iteration 171: time=0.02, ELBO=-53630.81, deltaELBO=0.247 (0.00007139%), Factors=7
# Iteration 172: time=0.02, ELBO=-53630.57, deltaELBO=0.241 (0.00006959%), Factors=7
# Iteration 173: time=0.02, ELBO=-53630.33, deltaELBO=0.237 (0.00006832%), Factors=7
# Iteration 174: time=0.02, ELBO=-53630.10, deltaELBO=0.234 (0.00006743%), Factors=7
# Iteration 175: time=0.02, ELBO=-53629.87, deltaELBO=0.232 (0.00006688%), Factors=7
# Iteration 176: time=0.02, ELBO=-53629.63, deltaELBO=0.231 (0.00006666%), Factors=7
# Iteration 177: time=0.02, ELBO=-53629.40, deltaELBO=0.231 (0.00006680%), Factors=7
# Iteration 178: time=0.02, ELBO=-53629.17, deltaELBO=0.233 (0.00006732%), Factors=7
# Iteration 179: time=0.02, ELBO=-53628.93, deltaELBO=0.236 (0.00006824%), Factors=7
# Iteration 180: time=0.02, ELBO=-53628.69, deltaELBO=0.241 (0.00006954%), Factors=7
# Iteration 181: time=0.02, ELBO=-53628.45, deltaELBO=0.246 (0.00007113%), Factors=7
# Iteration 182: time=0.02, ELBO=-53628.19, deltaELBO=0.252 (0.00007282%), Factors=7
# Iteration 183: time=0.02, ELBO=-53627.94, deltaELBO=0.257 (0.00007427%), Factors=7
# Iteration 184: time=0.02, ELBO=-53627.68, deltaELBO=0.260 (0.00007502%), Factors=7
# Iteration 185: time=0.02, ELBO=-53627.42, deltaELBO=0.258 (0.00007456%), Factors=7
# Iteration 186: time=0.02, ELBO=-53627.17, deltaELBO=0.251 (0.00007259%), Factors=7
# Iteration 187: time=0.02, ELBO=-53626.93, deltaELBO=0.240 (0.00006915%), Factors=7
# Iteration 188: time=0.02, ELBO=-53626.70, deltaELBO=0.224 (0.00006469%), Factors=7
# Iteration 189: time=0.02, ELBO=-53626.50, deltaELBO=0.207 (0.00005988%), Factors=7
# Iteration 190: time=0.02, ELBO=-53626.30, deltaELBO=0.192 (0.00005531%), Factors=7
# Iteration 191: time=0.02, ELBO=-53626.13, deltaELBO=0.178 (0.00005135%), Factors=7
# Iteration 192: time=0.02, ELBO=-53625.96, deltaELBO=0.167 (0.00004813%), Factors=7
# Iteration 193: time=0.02, ELBO=-53625.80, deltaELBO=0.158 (0.00004558%), Factors=7
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################
#
#
# Saving model in mofa_results/run_02_filtered_proteins.hdf5...

# %%
# Comparison
"""
Adapted from 
https://github.com/bioFAM/mofax/blob/master/notebooks/getting_started_pbmc10k.ipynb
"""

# Load MOFA+ outputs for 2 runs
m1 = mfx.mofa_model("mofa_results/run_01_only_ARD.hdf5")
m2 = mfx.mofa_model("mofa_results/run_02_filtered_proteins.hdf5")

# Basic model check 
n_features1 = m1.get_factors(df=True).shape[1]
n_features2 = m2.get_factors(df=True).shape[1]

print('='*15 + 'Model 1 – Full Data: Basic Model Check' + '='*37)
print(f"""\
Samples: {m1.shape[0]}
Features: {m1.shape[1]}
Groups of cells: {', '.join(m1.groups)}
Views: {', '.join(m1.views)}
Number of Latent Factors Found: {n_features1}
""")

print('='*15 + 'Model 2 – Filtered Proteins (2000): Basic Model Check' + '='*15)
print(f"""\
Samples: {m2.shape[0]}
Features: {m2.shape[1]}
Groups of cells: {', '.join(m2.groups)}
Views: {', '.join(m2.views)}
Number of Latent Factors Found: {n_features2}
""")
# Out:
# ===============Model 1 – Full Data: Basic Model Check=====================================
# Samples: 10
# Features: 8766
# Groups of cells: group1
# Views: proteomics, lipidomics, metabolomics
# Number of Latent Factors Found: 7
#
# ===============Model 2 – Filtered Proteins (2000): Basic Model Check===============
# Samples: 10
# Features: 3229
# Groups of cells: group1
# Views: proteomics, lipidomics, metabolomics
# Number of Latent Factors Found: 7

# %%
# Total Variance Explained  
def r2_per_view(model, model_name):
    return (
        model.get_r2()
             .groupby("View")["R2"]
             .sum()
             .rename(model_name)
    )

r2_table = pd.concat(
    [r2_per_view(m1, "Model 1"),
    r2_per_view(m2, "Model 2"),
    ], axis=1
)

print(r2_table)
# Out:
#                 Model 1    Model 2
# View
# lipidomics    68.389431  72.765711
# metabolomics  20.369884  23.733495
# proteomics    52.989725  76.115912

# %%
# Plots
output_dir = Path('plots/downstream_analysis')
output_dir.mkdir(parents=True, exist_ok=True)

var_sum1 = m1.get_r2(factors=list(range(n_features1)))
var_sum2 = m2.get_r2(factors=list(range(n_features2)))

fig, axs = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

df1 = (var_sum1.pivot(index="Factor", columns="View", values="R2").fillna(0))
df1.plot(
    kind="bar",
    stacked=True,
    width=0.5,
    ax=axs[0],
    colormap="viridis"
)

axs[0].set_ylabel("Variance explained (R²)")
axs[0].set_xlabel("Latent factor")
axs[0].set_title("Model 1 – Full Data: Variance explained per factor")
axs[0].legend(title="View")

df2 = (var_sum2.pivot(index="Factor", columns="View", values="R2").fillna(0))
df2.plot(
    kind="bar",
    stacked=True,
    width=0.5,
    ax=axs[1],
    colormap="viridis"
)

axs[1].set_ylabel("Variance explained (R²)")
axs[1].set_xlabel("Latent factor")
axs[1].set_title("Model 2 – Filtered Proteins: Variance explained per factor")
axs[1].legend(title="View")

plt.tight_layout()
plt.savefig(output_dir / 'variance_explained_comparison.png')
plt.show()

# %%
# Plot weights ranked cross-omics to inspect whether less dominant view(s) now contribute more meaningfully
""" 
Code adapted from the function .plot_weights_ranked() from the mofax package. Since the original function only plot ranked weights per view,
we have to manually create a new code to inspect this. 
Source: https://github.com/bioFAM/mofax/blob/master/mofax/plot_weights.py#L295C21-L302C1
"""

# Extract weights and Rank them according to their values. The higher the values, the stronger the correlation.
w1 = m1.get_weights(df=True)["Factor1"].copy()
w1 = w1.sort_values(ascending=False)
df1 = w1.reset_index()
df1.columns = ["feature", "value"]
df1["rank"] = range(1, len(df1)+1)

w2 = m2.get_weights(df=True)["Factor1"].copy()
w2 = w2.sort_values(ascending=False)
df2 = w2.reset_index()
df2.columns = ["feature", "value"]
df2["rank"] = range(1, len(df2)+1)

# Plot side-by-side ranked weights for each model
fig, axes = plt.subplots(1, 2, figsize=(10,5))

# Plot for Model 1 Full Data
axes[0].plot(df1["rank"], df1["value"], linewidth=0.8, alpha=0.9, color='black')
top_df1 = df1.head(15)
axes[0].scatter(
    top_df1["rank"],
    top_df1["value"],
    zorder=3,
    linewidth=0.2,
    alpha=0.75,
    color='black'
    
)

x_label_pos1 = 130
y_start1 = top_df1.iloc[0]["value"]

for i, (_, row) in enumerate(top_df1.iterrows()):
    axes[0].text(
        x_label_pos1,
        y_start1 - i*0.16,
        row["feature"],
        fontsize=7,
        ha="left"
    )

axes[0].set_xlabel("Feature rank")
axes[0].set_ylabel("Factor1 weights")
axes[0].set_title("Factor 1 Feature Weights (Model 1 – Full Data)")

# Plot for Model 2 Filtered Proteins
axes[1].plot(df2["rank"], df2["value"], linewidth=0.8, alpha=0.9, color='black')
top_df2 = df2.head(15)
axes[1].scatter(
    top_df2["rank"],
    top_df2["value"],
    zorder=3,
    linewidth=0.2,
    alpha=0.75,
    color='black'
    
)

x_label_pos2 = 130
y_start2 = top_df2.iloc[0]["value"]

for i, (_, row) in enumerate(top_df2.iterrows()):
    axes[1].text(
        x_label_pos2,
        y_start2 - i*0.16,
        row["feature"],
        fontsize=7,
        ha="left"
    )

axes[1].set_xlabel("Feature rank")
axes[1].set_ylabel("Factor1 weights")
axes[1].set_title("Factor 1 Feature Weights (Model 2 – Filtered Proteins)")

fig.tight_layout()
fig.show()
fig.savefig(output_dir / 'Factor1_Global_Weights_Ranked')

# %% [markdown]
# ## Phase 3 — Downstream Analysis
#
# 1. PCA plots for Factor 1 and 2 based on group labels (Macula vs. Periphery)
# 2. Top feature rankings per factor 1 and 2
# 3. GSEA / pathway enrichment (export gene/feature lists, run GSEA, save results)

# %%
# PCA plots for Factor 1 and 2 based on group labels (Macula vs. Periphery)
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms

def confidence_ellipse(x, y, ax, n_std=2.4477, facecolor='none', edgecolor='black', linestyle='--', **kwargs):
    """
    Create a confidence ellipse for a 2D dataset
    n_std=2.4477 corresponds to ~95% confidence for 2D
    """
    if len(x) < 3:
        return None
    
    cov = np.cov(x, y)
    mean_x, mean_y = np.mean(x), np.mean(y)
    
    # Calculate eigenvalues and eigenvectors
    eigvals, eigvecs = np.linalg.eigh(cov)
    order = eigvals.argsort()[::-1]
    eigvals, eigvecs = eigvals[order], eigvecs[:, order]
    
    # Calculate angle and width/height
    angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
    width, height = 2 * n_std * np.sqrt(eigvals)
    
    # Create ellipse
    ellipse = Ellipse(
        (mean_x, mean_y),
        width=width,
        height=height,
        angle=angle,
        facecolor=facecolor,
        edgecolor=edgecolor,
        linestyle=linestyle,
        linewidth=2,
        **kwargs
    )
    
    return ax.add_patch(ellipse)

def plot_mofa_factors_with_ellipses(
    model,
    labels: np.ndarray,
    run_name: str = "MOFA+ Factors",
    factor1: str = "Factor1",
    factor2: str = "Factor2",
    save_path: str = None,
    figsize: tuple = (10, 8)
):
    """
    Plot MOFA+ factors with 95% confidence ellipses using matplotlib
    
    Parameters:
    -----------
    model : hdf5 files
        Saved MOFA+ .hdf5 model
    labels : np.ndarray
        Sample class labels
    run_name : str
        Name for the plot title
    factor1 : str
        Name of first factor (e.g., 'Factor1')
    factor2 : str
        Name of second factor (e.g., 'Factor2')
    save_path : str
        Path to save the plot (optional)
    figsize : tuple
        Figure size (width, height)
    """

    # Get factors as DataFrame
    factors_df = model.get_factors(df=True)
    factors_df['label'] = labels
    
    # Create figure
    fig, ax = plt.subplots(figsize=figsize)
    
    # Get unique groups and colors
    unique_groups = factors_df['label'].unique()
    colors = sns.color_palette("husl", len(unique_groups))
    color_map = dict(zip(unique_groups, colors))
    
    # Plot scatter points for each group
    for group in unique_groups:
        group_data = factors_df[factors_df['label'] == group]
        ax.scatter(
            group_data[factor1],
            group_data[factor2],
            c=[color_map[group]],
            label=group,
            s=100,
            alpha=0.7,
            edgecolors='black',
            linewidth=0.5
        )
        
        # Add confidence ellipse
        if len(group_data) >= 3:
            confidence_ellipse(
                group_data[factor1].values,
                group_data[factor2].values,
                ax,
                edgecolor=color_map[group],
                linestyle='--',
                alpha=0.5
            )
    
    # Labels and title
    sample_names = factors_df.index.tolist()
    display_names = [f"S{name}" for name in sample_names]
    for i, display_name in enumerate(display_names):
        ax.annotate(
            display_name,
            (factors_df[factor1].iloc[i], factors_df[factor2].iloc[i]),
            xytext=(3, 3),
            textcoords='offset points',
            ha='left'
        )
    ax.set_xlabel(factor1, fontsize=12, fontweight='bold')
    ax.set_ylabel(factor2, fontsize=12, fontweight='bold')
    ax.set_title(f'{run_name}: {factor1} vs {factor2}\nwith 95% Confidence Ellipses', 
                 fontsize=14, fontweight='bold')
    
    # Legend
    ax.legend(loc='best', frameon=True, shadow=True)
    
    # Grid
    ax.grid(True, alpha=0.3, linestyle='--')
    
    # Tight layout
    plt.tight_layout()
    
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"Plot saved to {save_path}")
    
    plt.show()
    
    return factors_df

# %%
# Plot Factor 1 vs Factor 2 and Display factors values for Run 1 
plot_mofa_factors_with_ellipses(
    model=m1,
    labels=train1.labels,
    run_name="MOFA+ Run 1 (Full Data)",
    factor1='Factor1',
    factor2='Factor2',
    save_path=str(output_dir / 'run1_factors_F1_F2.png')
)
# Out:
# Plot saved to plots/downstream_analysis/run1_factors_F1_F2.png
#      Factor1   Factor2   Factor3   Factor4   Factor5   Factor6   Factor7  \
# 1  -1.197157  0.016756  0.369722  0.247292 -0.253947 -0.298418 -0.076167
# 2  -1.445803  0.334861 -0.248271 -0.026433  0.017104  0.144481 -0.094971
# 3  -1.517738 -0.564753 -0.076134 -0.128548  0.123315 -0.070965  0.111753
# 4  -1.404968 -0.082729 -0.024181  0.069406  0.127136  0.013374  0.138004
# 5  -1.455927  0.344739 -0.243043 -0.022494  0.017647  0.139560 -0.094247
# 6   0.931476  0.128586  0.924071  0.157959 -0.196924  0.212047  0.072424
# 7   1.360814 -1.201420 -0.628668 -0.228513 -0.232780  0.039453 -0.024439
# 8   1.346366 -0.338089  0.694605 -0.213767  0.347707 -0.036497 -0.101509
# 9   1.982001  0.096498 -0.606401  0.578999  0.150400 -0.046458  0.013705
# 10  1.400935  1.265550 -0.161699 -0.433901 -0.099657 -0.096576  0.055447
#
#         label
# 1      Macula
# 2      Macula
# 3      Macula
# 4      Macula
# 5      Macula
# 6   Periphery
# 7   Periphery
# 8   Periphery
# 9   Periphery
# 10  Periphery

# %%
# Plot Factor 1 vs Factor 2 and Display factors values for Run 2
plot_mofa_factors_with_ellipses(
    model=m2,
    labels=train2.labels,
    run_name="MOFA+ Run 2 (Filtered Proteins)",
    factor1='Factor1',
    factor2='Factor2',
    save_path=str(output_dir / 'run2_factors_F1_F2.png')
)
# Out:
# Plot saved to plots/downstream_analysis/run2_factors_F1_F2.png
#      Factor1   Factor2   Factor3   Factor4   Factor5   Factor6   Factor7  \
# 1  -1.077787 -0.129368 -0.404317 -0.231847 -0.432679 -0.153355 -0.167907
# 2  -1.372701  0.173780  0.058170 -0.014311  0.108054  0.216174 -0.028514
# 3  -1.378005 -0.396491  0.226310  0.284470  0.146104 -0.174258 -0.014059
# 4  -1.207094  0.065982  0.052154 -0.125802  0.128501 -0.165166  0.193918
# 5  -1.371783  0.192949  0.040892 -0.033558  0.099419  0.217132 -0.027251
# 6   0.967610 -0.161562 -0.651601 -0.263837 -0.289210  0.107290  0.183385
# 7   1.091455 -0.087796  1.269815  0.098685 -0.265314  0.033040  0.030991
# 8   1.412441 -0.534727 -0.330670  0.390784  0.200060  0.088343 -0.041985
# 9   1.664080  0.119031  0.136019 -0.643972  0.339930 -0.106236 -0.103373
# 10  1.271783  0.758201 -0.396773  0.539388 -0.034865 -0.062963 -0.025205
#
#         label
# 1      Macula
# 2      Macula
# 3      Macula
# 4      Macula
# 5      Macula
# 6   Periphery
# 7   Periphery
# 8   Periphery
# 9   Periphery
# 10  Periphery
